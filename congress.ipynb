# %% [markdown]
# <a href="https://colab.research.google.com/github/brianmulyadi/Designing-Data-Products/blob/main/congress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DDP Notebook - Version 1

# %% [markdown]
# Link to Calvin's repository on his DDP project on [Loan Analysis](https://github.com/calvintirrell/Loan_Analysis)

# %%
# install Kaggle
# !pip install -q kaggle
from google.colab import files
files.upload()

# %%
# create a Kaggle folder
# !mkdir ~/.kaggle

# copy the kaggle.json to Kaggle folder
# !cp kaggle.json ~/.kaggle/

# change permission to kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# insert dataset
# !kaggle datasets download -d brianmulyadi/congress-api

# unzip folder
# !unzip congress-api.zip
# Out:
# ...
#   0% 0.00/91.4k [00:00<?, ?B/s]
# 100% 91.4k/91.4k [00:00<00:00, 52.7MB/s]

# %%
# read csv using pandas and numpy
import numpy as np
import pandas as pd

df = pd.read_csv("0-99.csv")
df.head()
# Out:
#                   policyArea latestAction  \
# 0                   Commerce       5/6/22
# 1           Native Americans      5/12/22
# 2                     Health      4/29/22
# 3       Agriculture and Food      3/10/21
# 4  Crime and Law Enforcement      4/14/22
#
#                                              sponsor  \
# 0  P000616|Rep. Phillips, Dean [D-MN-3]|Dean||Phi...
# 1  N000191|Rep. Neguse, Joe [D-CO-2]|Joe||Neguse|...
# 2  M001157|Rep. McCaul, Michael T. [R-TX-10]|Mich...
# 3  P000610|Del. Plaskett, Stacey E. [D-VI-At Larg...
# 4  K000397|Rep. Kim, Young [R-CA-39]|Young||Kim|R...
#
#                                           coSponsors introducedDate  \
# 0  H001072|Rep. Hill, J. French [R-AR-2]|J.|Frenc...         5/6/22
# 1  B000574|Rep. Blumenauer, Earl [D-OR-3]|EARL||B...        4/28/22
# 2  S001175|Rep. Speier, Jackie [D-CA-14]|Jackie||...        4/28/22
# 3  F000449|Rep. Fortenberry, Jeff [R-NE-1]|Jeff||...        3/10/21
# ...

# %%
df.describe()
# Out:
#                                 policyArea latestAction  \
# count                                   99          100
# unique                                  24           58
# top     Government Operations and Politics     10/11/22
# freq                                    25           11
#
#                                                   sponsor  \
# count                                                 100
# unique                                                 77
# top     M000087|Rep. Maloney, Carolyn B. [D-NY-12]|CAR...
# freq                                                    5
#
#                                                coSponsors introducedDate  \
# count                                                  88             99
# unique                                                 85             70
# top     W000795|Rep. Wilson, Joe [R-SC-2]|Joe||Wilson|...        9/26/22
# freq                                                    3              6
#
# ...
